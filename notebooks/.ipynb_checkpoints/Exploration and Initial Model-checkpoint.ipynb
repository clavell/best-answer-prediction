# %% [markdown]
# To get all of this to run correctly we need to be in the correct python environment. Using Anaconda Here are the steps:
# - conda create -n tf tensorflow
# - conda activate tf
# - conda install pandas
# - conda install matplotlib

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as et
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xml_file = 'stackexchange_data/diy.stackexchange.com/Posts_original.xml'
originaldf = pd.read_xml(xml_file,attrs_only=True,parser='etree')
originaldf.describe()
# Out:
#        AcceptedAnswerId   AnswerCount   CommentCount  FavoriteCount  \
# count      22593.000000  64503.000000  173341.000000    7136.000000
# mean      108373.832957      1.677674       1.950046       1.478840
# std        70620.506794      1.453162       2.619226       2.210341
# min            9.000000      0.000000       0.000000       0.000000
# 25%        41791.000000      1.000000       0.000000       1.000000
# 50%       106801.000000      1.000000       1.000000       1.000000
# 75%       170870.000000      2.000000       3.000000       1.000000
# max       234205.000000     77.000000      48.000000      74.000000
#
#                   Id  LastEditorUserId    OwnerUserId     PostTypeId  \
# count  173341.000000      60843.000000  171425.000000  173341.000000
# mean   118908.775829      34969.900580   48320.166283       1.637080
# std     67767.548143      35088.478365   38686.024289       0.514955
# min         1.000000         -1.000000      -1.000000       1.000000
# 25%     62355.000000       2196.000000   14437.000000       1.000000
# 50%    121874.000000      27773.000000   44366.000000       2.000000
# 75%    177914.000000      55930.000000   74694.000000       2.000000
# max    234210.000000     141224.000000  141255.000000       7.000000
#
#                Score      ViewCount       ParentId
# count  173341.000000   64503.000000  108215.000000
# mean        2.130540    4921.380509  110062.501077
# std         4.200341   20640.046517   69797.636240
# min       -21.000000       4.000000       1.000000
# 25%         0.000000     100.000000   47171.000000
# 50%         1.000000     457.000000  108629.000000
# 75%         2.000000    2333.000000  171230.000000
# max       300.000000  877087.000000  234198.000000

# %%
originaldf.describe(exclude=[np.number])
# Out:
#                                                      Body ContentLicense  \
# count                                              173169         173341
# unique                                             173154              3
# top     There's no need to use this tag.  When asking ...   CC BY-SA 3.0
# freq                                                    3          93808
#
#                    CreationDate         LastActivityDate  \
# count                    173341                   173341
# unique                   172934                   137337
# top     2011-10-16T21:46:14.993  2010-07-21T19:33:18.130
# freq                          2                        2
#
#                    LastEditDate          Tags                          Title  \
# count                     61226         64503                          64503
# unique                    57713         28755                          64493
# top     2020-06-16T10:07:27.010  <electrical>  Does this look like asbestos?
# freq                       1941          2761                              2
#
#        OwnerDisplayName       CommunityOwnedDate LastEditorDisplayName  \
# count              2671                      469                   395
# unique             1260                      406                   105
# top             user558  2011-10-19T10:49:56.827             user39367
# freq                238                        9                    68
#
#                      ClosedDate
# count                      2440
# unique                     2440
# top     2012-09-11T19:17:04.623
# freq                          1

# %% [markdown]
# according to survey characteristics of good answers are :
# - More varied vocabulary
# - Answers referenced by other answers
# - More comments from other users
# - Earlier posted answers are likely to be better
# - Answer most different from the rest
# - Answer length (best)
# - Forum specific
#  easiest to look at are the answer length, time of posting and number of comments from other users.
# goal of this research is to find best answer. More interesting features are answers that are different from the rest. How to calculate answer similarity remains to be seen..
# ###### start with comment count, answer length and time of posting? easy low hanging fruit

# %%
originaldf.loc[originaldf['PostTypeId'] == 2]
# Out:
#         AcceptedAnswerId  AnswerCount  \
# 7                    NaN          NaN
# 10                   NaN          NaN
# 11                   NaN          NaN
# 12                   NaN          NaN
# 13                   NaN          NaN
# ...                  ...          ...
# 173330               NaN          NaN
# 173332               NaN          NaN
# 173333               NaN          NaN
# 173335               NaN          NaN
# 173340               NaN          NaN
#
#                                                      Body  CommentCount  \
# 7       <p>I've found that it works OK, but it's more ...             1
# 10      <p>I have used it for patching areas, but not ...             0
# 11      <p>I <em>just</em> caulked my shower last nigh...             3
# 12      <p>It's just an ornamental wall it sounds like...             3
# 13      <p>I just bought a permanent silicone product ...             3
# ...                                                   ...           ...
# 173330  <p>You have two choices (see sketch) - 1) Cont...             0
# 173332  <p>i just had problems with my trimmer not goi...             0
# 173333  <p>A routine repair of 2 cycle engines is repl...             0
# 173335  <p>I take it by the fact that you linked to an...             0
# 173340  <p>To keep other gray water from backing up in...             0
#
#        ContentLicense             CreationDate  FavoriteCount      Id  \
# 7        CC BY-SA 2.5  2010-07-21T19:19:02.440            NaN       9
# 10       CC BY-SA 2.5  2010-07-21T19:20:53.980            NaN      12
# 11       CC BY-SA 2.5  2010-07-21T19:21:15.583            NaN      13
# 12       CC BY-SA 2.5  2010-07-21T19:21:41.073            NaN      14
# 13       CC BY-SA 2.5  2010-07-21T19:22:00.623            NaN      15
# ...               ...                      ...            ...     ...
# 173330   CC BY-SA 4.0  2021-09-04T23:57:43.217            NaN  234200
# 173332   CC BY-SA 4.0  2021-09-05T00:12:14.867            NaN  234202
# 173333   CC BY-SA 4.0  2021-09-05T00:25:11.227            NaN  234203
# 173335   CC BY-SA 4.0  2021-09-05T01:19:37.370            NaN  234205
# 173340   CC BY-SA 4.0  2021-09-05T04:35:47.773            NaN  234210
#
#                LastActivityDate             LastEditDate  ...  PostTypeId  \
# 7       2010-07-21T19:19:02.440                     None  ...           2
# 10      2010-07-21T19:30:57.840  2010-07-21T19:30:57.840  ...           2
# 11      2010-07-22T00:31:43.253  2010-07-22T00:31:43.253  ...           2
# 12      2010-07-21T19:21:41.073                     None  ...           2
# 13      2010-07-21T19:22:00.623                     None  ...           2
# ...                         ...                      ...  ...         ...
# 173330  2021-09-05T00:07:56.280  2021-09-05T00:07:56.280  ...           2
# 173332  2021-09-05T00:12:14.867                     None  ...           2
# 173333  2021-09-05T00:25:11.227                     None  ...           2
# 173335  2021-09-05T01:19:37.370                     None  ...           2
# 173340  2021-09-05T04:35:47.773                     None  ...           2
#
#         Score  Tags  Title ViewCount  ParentId  OwnerDisplayName  \
# 7          11  None   None       NaN       3.0              None
# 10          6  None   None       NaN       3.0              None
# 11         13  None   None       NaN       2.0              None
# 12          4  None   None       NaN       1.0              None
# 13          5  None   None       NaN       2.0              None
# ...       ...   ...    ...       ...       ...               ...
# 173330      1  None   None       NaN  146674.0              None
# 173332      0  None   None       NaN   46938.0              None
# 173333      0  None   None       NaN   46938.0              None
# 173335      1  None   None       NaN  234187.0              None
# 173340      1  None   None       NaN  214731.0              None
#
#         CommunityOwnedDate LastEditorDisplayName ClosedDate
# 7                     None                  None       None
# 10                    None                  None       None
# 11                    None                  None       None
# 12                    None                  None       None
# 13                    None                  None       None
# ...                    ...                   ...        ...
# 173330                None                  None       None
# 173332                None                  None       None
# 173333                None                  None       None
# 173335                None                  None       None
# 173340                None                  None       None
#
# [108215 rows x 22 columns]

# %%
#html tags in body columns with blank space
originaldf.Body = originaldf.Body.str.replace('<[^>]*>','', regex=True)

# %%
# Need a difference between answer posting time and question posting time

from datetime import datetime 

datestrings = originaldf.CreationDate.str.slice_replace(start=-4)

dateObjects = []
for i in range(len(datestrings)):
    dateObjects.append(datetime.strptime(datestrings[i],'%Y-%m-%dT%H:%M:%S'))
    
originaldf.CreationDate = dateObjects

# %%
# for x in originaldf.columns:
#     print(x, originaldf[x].dtypes)

# %%
# want the question posting time for each answer
# so merge each answer with its question along with the body and creation date of the question
df = pd.merge(left=originaldf.loc[originaldf['PostTypeId'] == 2,['Id', 'CreationDate','Body','CommentCount','ParentId']], right=originaldf[['Id','AcceptedAnswerId', 'Body','CreationDate']],  left_on="ParentId", right_on="Id", how="left", suffixes=("_answer", "_question"))

# %%
df['is_accepted_answer'] = df.Id_answer == df.AcceptedAnswerId

# %%
df
# Out:
#         Id_answer CreationDate_answer  \
# 0               9 2010-07-21 19:19:02
# 1              12 2010-07-21 19:20:53
# 2              13 2010-07-21 19:21:15
# 3              14 2010-07-21 19:21:41
# 4              15 2010-07-21 19:22:00
# ...           ...                 ...
# 108210     234200 2021-09-04 23:57:43
# 108211     234202 2021-09-05 00:12:14
# 108212     234203 2021-09-05 00:25:11
# 108213     234205 2021-09-05 01:19:37
# 108214     234210 2021-09-05 04:35:47
#
#                                               Body_answer  CommentCount  \
# 0       I've found that it works OK, but it's more dif...             1
# 1       I have used it for patching areas, but not for...             0
# 2       I just caulked my shower last night. I used GE...             3
# 3       It's just an ornamental wall it sounds like, s...             3
# 4       I just bought a permanent silicone product by ...             3
# ...                                                   ...           ...
# 108210  You have two choices (see sketch) - 1) Continu...             0
# 108211  i just had problems with my trimmer not going ...             0
# 108212  A routine repair of 2 cycle engines is replace...             0
# 108213  I take it by the fact that you linked to an eB...             0
# 108214  To keep other gray water from backing up into ...             0
#
#         ParentId  Id_question  AcceptedAnswerId  \
# 0            3.0            3               9.0
# 1            3.0            3               9.0
# 2            2.0            2              13.0
# 3            1.0            1              38.0
# 4            2.0            2              13.0
# ...          ...          ...               ...
# 108210  146674.0       146674               NaN
# 108211   46938.0        46938               NaN
# 108212   46938.0        46938               NaN
# 108213  234187.0       234187          234205.0
# 108214  214731.0       214731               NaN
#
#                                             Body_question  \
# 0       I'm going to be doing some drywalling shortly ...
# 1       I'm going to be doing some drywalling shortly ...
# 2       I would like to recaulk between the bathtub an...
# 3       I'm looking to finish my basement and simply w...
# 4       I would like to recaulk between the bathtub an...
# ...                                                   ...
# 108210  I'm in the initial stages of planing a structu...
# 108211  My weed eater primer/gas line has more air in ...
# 108212  My weed eater primer/gas line has more air in ...
# 108213  I have a hand me down Weller Mini-Shop power t...
# 108214  We recently moved into a new (to us) house wit...
#
#        CreationDate_question  is_accepted_answer
# 0        2010-07-21 19:16:23                True
# 1        2010-07-21 19:16:23               False
# 2        2010-07-21 19:15:17                True
# 3        2010-07-21 19:14:06               False
# 4        2010-07-21 19:15:17               False
# ...                      ...                 ...
# 108210   2018-09-09 13:40:17               False
# 108211   2014-08-02 14:17:56               False
# 108212   2014-08-02 14:17:56               False
# 108213   2021-09-04 19:56:48                True
# 108214   2021-01-24 05:36:22               False
#
# [108215 rows x 10 columns]

# %%
# Don't think i need this anymore

# need a variable to show that the post was selected or not: do a left join with self
# left join variable is Id and right join variable is AcceptedAnswerId
# df = pd.merge(left=originaldf.loc[originaldf['PostTypeId'] == 2,['Id', 'CreationDate','Body','CommentCount']], right=originaldf[['Id','AcceptedAnswerId', 'Body','CreationDate']],  left_on="Id", right_on="AcceptedAnswerId", how="left", suffixes=("_answer", "_question")).drop(['AcceptedAnswerId'], axis=1)



# originaldata.loc[originaldata['column_name'] == some_value, [col_name1, col_name2]]

# %%
df['time_difference'] = df.CreationDate_answer - df.CreationDate_question

# %%
for i in range(len(df.time_difference)):
    if str( df.time_difference[i] ) == 'NaT':  
        print(df.time_difference[i])

# %%
time_difference_in_seconds = []

for i in range(len(df.time_difference)):
        time_difference_in_seconds.append(df.time_difference[i].total_seconds())
        
df.time_difference = time_difference_in_seconds

# %%
df.AcceptedAnswerId.isna().sum()
# Out:
# 62026

# %%
originaldf.isna().sum()
# Out:
# AcceptedAnswerId         150748
# AnswerCount              108838
# Body                        172
# CommentCount                  0
# ContentLicense                0
# CreationDate                  0
# FavoriteCount            166205
# Id                            0
# LastActivityDate              0
# LastEditDate             112115
# LastEditorUserId         112498
# OwnerUserId                1916
# PostTypeId                    0
# Score                         0
# Tags                     108838
# Title                    108838
# ViewCount                108838
# ParentId                  65126
# OwnerDisplayName         170670
# CommunityOwnedDate       172872
# LastEditorDisplayName    172946
# ClosedDate               170901
# dtype: int64

# %%
originaldf.loc[originaldf["PostTypeId"] == 1].shape
# Out:
# (64503, 22)

# %%
originaldf.loc[originaldf["PostTypeId"] == 1].isna().sum()
# Out:
# AcceptedAnswerId         41910
# AnswerCount                  0
# Body                         0
# CommentCount                 0
# ContentLicense               0
# CreationDate                 0
# FavoriteCount            57367
# Id                           0
# LastActivityDate             0
# LastEditDate             31375
# LastEditorUserId         31502
# OwnerUserId                656
# PostTypeId                   0
# Score                        0
# Tags                         0
# Title                        0
# ViewCount                    0
# ParentId                 64503
# OwnerDisplayName         63386
# CommunityOwnedDate       64475
# LastEditorDisplayName    64372
# ClosedDate               62063
# dtype: int64

# %% [markdown]
# So it looks like only ~12000 of the 64000 questions have chosen answers. As there won't be reliable examples of chosen answers for the remaining 42000 we will remove them from the training set.

# %%
df.shape
# Out:
# (108215, 11)

# %%
#Assume that if there are no AcceptedAnswerId for the question then
df.dropna(subset=["AcceptedAnswerId"],inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (46189, 11)

# %%
df.AcceptedAnswerId
# Out:
# 0             9.0
# 1             9.0
# 2            13.0
# 3            38.0
# 4            13.0
#            ...
# 46184    234205.0
# 46185    234192.0
# 46186    234205.0
# 46187    234172.0
# 46188    234205.0
# Name: AcceptedAnswerId, Length: 46189, dtype: float64

# %%
df.drop(['ParentId'], axis=1, inplace=True)

# %%
answer_lengths = []
for body in df.Body_answer:
    answer_lengths.append(len(body.split()))
df['answer_length'] = answer_lengths

# %%
df
# Out:
#        Id_answer CreationDate_answer  \
# 0              9 2010-07-21 19:19:02
# 1             12 2010-07-21 19:20:53
# 2             13 2010-07-21 19:21:15
# 3             14 2010-07-21 19:21:41
# 4             15 2010-07-21 19:22:00
# ...          ...                 ...
# 46184     234190 2021-09-04 20:51:25
# 46185     234192 2021-09-04 21:33:36
# 46186     234195 2021-09-04 22:42:39
# 46187     234197 2021-09-04 23:16:53
# 46188     234205 2021-09-05 01:19:37
#
#                                              Body_answer  CommentCount  \
# 0      I've found that it works OK, but it's more dif...             1
# 1      I have used it for patching areas, but not for...             0
# 2      I just caulked my shower last night. I used GE...             3
# 3      It's just an ornamental wall it sounds like, s...             3
# 4      I just bought a permanent silicone product by ...             3
# ...                                                  ...           ...
# 46184  What to look for:\nIt will have a firm attachm...             0
# 46185  With the tabs intact the receptacles both are ...             2
# 46186  Dremel tools are high quality and go up to 350...             0
# 46187  It looks like something home made, and possibl...             1
# 46188  I take it by the fact that you linked to an eB...             0
#
#        Id_question  AcceptedAnswerId  \
# 0                3               9.0
# 1                3               9.0
# 2                2              13.0
# 3                1              38.0
# 4                2              13.0
# ...            ...               ...
# 46184       234187          234205.0
# 46185       234149          234192.0
# 46186       234187          234205.0
# 46187       234158          234172.0
# 46188       234187          234205.0
#
#                                            Body_question  \
# 0      I'm going to be doing some drywalling shortly ...
# 1      I'm going to be doing some drywalling shortly ...
# 2      I would like to recaulk between the bathtub an...
# 3      I'm looking to finish my basement and simply w...
# 4      I would like to recaulk between the bathtub an...
# ...                                                  ...
# 46184  I have a hand me down Weller Mini-Shop power t...
# 46185  Before moving into our house recently I had in...
# 46186  I have a hand me down Weller Mini-Shop power t...
# 46187  My home has a 17” x 36” x 1” shelf that appear...
# 46188  I have a hand me down Weller Mini-Shop power t...
#
#       CreationDate_question  is_accepted_answer  time_difference  \
# 0       2010-07-21 19:16:23                True            159.0
# 1       2010-07-21 19:16:23               False            270.0
# 2       2010-07-21 19:15:17                True            358.0
# 3       2010-07-21 19:14:06               False            455.0
# 4       2010-07-21 19:15:17               False            403.0
# ...                     ...                 ...              ...
# 46184   2021-09-04 19:56:48               False           3277.0
# 46185   2021-09-03 22:31:37                True          82919.0
# 46186   2021-09-04 19:56:48               False           9951.0
# 46187   2021-09-04 02:05:10               False          76303.0
# 46188   2021-09-04 19:56:48                True          19369.0
#
#        answer_length
# 0                 48
# 1                 37
# 2                 81
# 3                 56
# 4                 30
# ...              ...
# 46184             50
# 46185            145
# 46186             26
# 46187             27
# 46188            193
#
# [46189 rows x 11 columns]

# %% [markdown]
# # Training The Neural Network
# Now that there is a basic preprocessing of the data, we can train a classification model on it. As it stands right now there is no association between different answers that are in the same thread. Each entry in the datframe is an answer which could be classified as the chosen answer or not. This means that multiple questions could be classified by the algorithm as the chosen answer. We will see if this behaviour has a drastic effect. It seems more complicated to have the classifier choose only one answer per thread, so we will see how this more simple model performs before we move on to a more complicated data structure.

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.pipeline import Pipeline
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.0.0
# 2.2.4-tf

# %%
from sklearn.model_selection import train_test_split

# %%
# do a train test split on the data
test_size = 0.2
train_full_size = 1-test_size
dev_size = test_size/train_full_size
# get the features discussed above
features = df[['CommentCount', 'time_difference', 'answer_length']]
labels = df.is_accepted_answer

# %%
# From: https://stackoverflow.com/questions/34842405/parameter-stratify-from-method-train-test-split-scikit-learn
X_train_full, X_test, y_train_full, y_test = train_test_split(features, labels,test_size=test_size,stratify=labels,random_state=92)

# %%
# also create a dev set
X_train, X_dev, y_train, y_dev = train_test_split(X_train_full, y_train_full,test_size=dev_size,stratify=y_train_full,random_state=11)

# %%
[X_train.shape,X_dev.shape,X_test.shape]
# Out:
# [(27713, 3), (9238, 3), (9238, 3)]

# %%
# model = keras.models.Sequential()
# model.add(keras.layers.Input(shape=[3]))
# model.add(keras.layers.Dense(8, activation="sigmoid"))
# model.add(keras.layers.Dense(8, activation="sigmoid"))
# model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
def model():
    model = keras.models.Sequential([
        keras.layers.Input(shape=[3]),
        keras.layers.Dense(8, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
    return model

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2,
                                                  restore_best_weights=True,
                                                  monitor='accuracy')

# %%
pipeline = Pipeline(steps=[('neuralnet', 
                            KerasClassifier(build_fn=model, 
                                             epochs=10,
                                             validation_data=(X_dev.values, y_dev.values),
                                             callbacks=[early_stopping_cb]
                                           ))])

# %%
history = pipeline.fit(X_train.values, y_train.values)
# Out:
# Train on 27713 samples, validate on 9238 samples
# Epoch 1/10
# 27713/27713 [==============================] - 5s 194us/sample - loss: 1358117.8004 - accuracy: 0.5094 - val_loss: 0.6924 - val_accuracy: 0.5119
# Epoch 2/10
# 27713/27713 [==============================] - 3s 117us/sample - loss: 0.6923 - accuracy: 0.5124 - val_loss: 0.6922 - val_accuracy: 0.5119
# Epoch 3/10
# 27713/27713 [==============================] - 3s 119us/sample - loss: 0.6920 - accuracy: 0.5124 - val_loss: 0.6923 - val_accuracy: 0.5118
# Epoch 4/10
# 27713/27713 [==============================] - 3s 114us/sample - loss: 0.6921 - accuracy: 0.5124 - val_loss: 0.6922 - val_accuracy: 0.5119
# Epoch 5/10
# 27713/27713 [==============================] - 3s 120us/sample - loss: 0.6920 - accuracy: 0.5125 - val_loss: 0.6922 - val_accuracy: 0.5119
# Epoch 6/10
# 27713/27713 [==============================] - 3s 112us/sample - loss: 0.6922 - accuracy: 0.5126 - val_loss: 0.6926 - val_accuracy: 0.5123
# Epoch 7/10
# 27713/27713 [==============================] - 4s 129us/sample - loss: 0.6921 - accuracy: 0.5127 - val_loss: 0.6922 - val_accuracy: 0.5123
# Epoch 8/10
# 27713/27713 [==============================] - 3s 113us/sample - loss: 0.6917 - accuracy: 0.5128 - val_loss: 0.6927 - val_accuracy: 0.5122
# Epoch 9/10
# 27713/27713 [==============================] - 3s 113us/sample - loss: 0.6917 - accuracy: 0.5130 - val_loss: 0.6949 - val_accuracy: 0.5121
# Epoch 10/10
# 27713/27713 [==============================] - 3s 119us/sample - loss: 0.6918 - accuracy: 0.5130 - val_loss: 0.6924 - val_accuracy: 0.5124

# %%
# pd.DataFrame(history.history).plot(figsize=(8, 5))
# plt.grid(True)
# plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
# plt.show()

# %%
pipeline['neuralnet']

# %%
X_train.shape[1:]
# Out:
# (3,)

# %%
y_pred_train = pipeline.predict(X_train.values)

# %%
y_pred_train
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
y_pred_train.sum()
# Out:
# 61

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.51      1.00      0.68     14158
#         True       0.95      0.00      0.01     13555
#
#     accuracy                           0.51     27713
#    macro avg       0.73      0.50      0.34     27713
# weighted avg       0.73      0.51      0.35     27713

# %% [markdown]
# so far all predictions are that the answers are poor. Now need to normalize the values for each thread as there can be a wide range in the number of comments, number of words in given answers or amount of time between question and answer.
